# %%
import sys
sys.path.append("../..")

# %%
# %matplotlib inline

# %%
from tangle.analysis.graph import Graph
import json

# %%
with open('tangle_walk_many_highalpha.json', "r") as tf:
    data = json.load(tf)
    hgraph = Graph(data, 100, './highalpha')

with open('tangle_walk_many_alpha1.json', "r") as tf:
    data = json.load(tf)
    mgraph = Graph(data, 100, './alpha1')

with open('tangle_walk_many_lowalpha.json', "r") as tf:
    data = json.load(tf)
    lgraph = Graph(data, 100, './lowalpha')

# %%
hgraph.plot_total_participating_clients_per_round(plot_for_paper=True)

# %%
mgraph.plot_total_participating_clients_per_round()

# %%
lgraph.plot_total_participating_clients_per_round()

# %%
hgraph.plot_modularity_per_round()

# %%
mgraph.plot_modularity_per_round()

# %%
lgraph.plot_modularity_per_round()

# %%
hgraph.plot_num_modules_per_round()

# %%
mgraph.plot_num_modules_per_round()

# %%
lgraph.plot_num_modules_per_round()

# %%
hgraph.plot_misclassification_per_round()

# %%
mgraph.plot_misclassification_per_round()

# %%
lgraph.plot_misclassification_per_round()
